# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import os
import pandas as pd
import numpy as np
import sys

# %%
path_to_dlc_output = '/Users/johnmarshall/Dropbox (Personal)/ReferenceForSummerStudents/deeplabcut_example/behavCam4DLC_resnet50_GRIN_rotarod_rearviewApr2shuffle1_300000.h5'

dlc_df = pd.read_hdf(path_to_dlc_output)

# %%
#view dlc dataframe 
dlc_df
# Out:
# scorer    DLC_resnet50_GRIN_rotarod_rearviewApr2shuffle1_300000              \
# bodyparts                                             tail_base
# coords                                                        x           y
# 0                                                 164.360962     422.966858
# 1                                                 164.142502     426.620392
# 2                                                 164.250504     429.101624
# 3                                                 161.948166     433.902985
# 4                                                 152.797852     435.625031
# ..                                                       ...            ...
# 995                                               156.028320     417.945251
# 996                                               155.938431     418.069275
# 997                                               155.562531     417.445984
# ...
